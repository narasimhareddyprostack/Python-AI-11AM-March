# %%
sizes=[38,40,42,44]   #list object
sizes[0]=39
sizes.append(46)
print(sizes)
# Out:
# [39, 40, 42, 44, 46]

# %%
eids={101,102,101,101,101}
print(eids)
# Out:
# {101, 102}

# %%
eids={101,102,101,101,101}
eids.add(103)
print(eids)
# Out:
# {101, 102, 103}

# %%
emp={
    'eid':101,
    'ename':'Rahul'
}
emp['ename']='Rahul Gandhi'
emp['loc']='Wayanad'
print(emp)
# Out:
# {'eid': 101, 'ename': 'Rahul Gandhi', 'loc': 'Wayanad'}

# %%
b=bytes([10,20,30,256])
print(b)
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 b=bytes([10,20,30,256])
#       2 print(b)
#
# ValueError: bytes must be in range(0, 256)

# %%
b=bytes([10,20,30,255])
print(b)
b[0]=11
for ele in b:
    print(ele)
# Out:
# b'\n\x14\x1e\xff'
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In[8], line 3
#       1 b=bytes([10,20,30,255])
#       2 print(b)
# ----> 3 b[0]=11
#       4 for ele in b:
#       5     print(ele)
#
# TypeError: 'bytes' object does not support item assignment

# %%
ba=bytearray([10,20,30,255])
print(ba)
ba[0]=11
ba[1]=21
ba[2]=31
for ele in ba:
    print(ele)
# Out:
# bytearray(b'\n\x14\x1e\xff')
# 11
# 21
# 31
# 255
